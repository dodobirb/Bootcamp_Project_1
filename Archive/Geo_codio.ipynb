# %%
from geocodio import GeocodioClient
from dotenv import load_dotenv

load_dotenv()

geo_api_key = os.getenv("GEOCODIO_API_KEY")

client = GeocodioClient(geo_api_key)

# %%
location = client.geocode("Philadelphia, PA")

print(location)
# Out:
# {'input': {'address_components': {'city': 'Philadelphia', 'state': 'PA', 'country': 'US'}, 'formatted_address': 'Philadelphia, PA'}, 'results': [{'address_components': {'city': 'Philadelphia', 'county': 'Philadelphia County', 'state': 'PA', 'zip': '19101', 'country': 'US'}, 'formatted_address': 'Philadelphia, PA 19101', 'location': {'lat': 40.001811, 'lng': -75.11787}, 'accuracy': 1, 'accuracy_type': 'place', 'source': 'TIGER/Line® dataset from the US Census Bureau'}, {'address_components': {'city': 'Philadelphia', 'county': 'Philadelphia County', 'state': 'PA', 'zip': '19102', 'country': 'US'}, 'formatted_address': 'Philadelphia, PA 19102', 'location': {'lat': 39.952562, 'lng': -75.166472}, 'accuracy': 1, 'accuracy_type': 'place', 'source': 'TIGER/Line® dataset from the US Census Bureau'}, {'address_components': {'city': 'Philadelphia', 'county': 'Philadelphia County', 'state': 'PA', 'zip': '19103', 'country': 'US'}, 'formatted_address': 'Philadelphia, PA 19103', 'location': {'lat':
# ...
